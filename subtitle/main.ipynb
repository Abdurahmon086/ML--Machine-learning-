# %%
# !pip install moviepy==2.0.0.dev2
# !pip install imageio==2.25.1
# !apt install imagemagick
# !cat /etc/ImageMagick-6/policy.xml | sed 's/none/read,write/g'> /etc/ImageMagick-6/policy.xml
# !pip install pysrt==1.1.2
# !pip install google-colab

from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Requirement already satisfied: moviepy==2.0.0.dev2 in c:\python312\lib\site-packages (2.0.0.dev2)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\python312\lib\site-packages (from moviepy==2.0.0.dev2) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\python312\lib\site-packages (from moviepy==2.0.0.dev2) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\python312\lib\site-packages (from moviepy==2.0.0.dev2) (0.4.9)
# Requirement already satisfied: numpy>=1.17.3 in c:\python312\lib\site-packages (from moviepy==2.0.0.dev2) (1.26.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\python312\lib\site-packages (from moviepy==2.0.0.dev2) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\python312\lib\site-packages (from moviepy==2.0.0.dev2) (0.1.10)
# Requirement already satisfied: pillow>=8.3.2 in c:\python312\lib\site-packages (from imageio<3.0,>=2.5->moviepy==2.0.0.dev2) (10.3.0)
# Requirement already satisfied: setuptools in c:\python312\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy==2.0.0.dev2) (69.2.0)
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (from proglog<=1.0.0->moviepy==2.0.0.dev2) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy==2.0.0.dev2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy==2.0.0.dev2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy==2.0.0.dev2) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy==2.0.0.dev2) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\abdurahmon\appdata\roaming\python\python312\site-packages (from tqdm->proglog<=1.0.0->moviepy==2.0.0.dev2) (0.4.6)
# Requirement already satisfied: imageio==2.25.1 in c:\python312\lib\site-packages (2.25.1)
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (from imageio==2.25.1) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in c:\python312\lib\site-packages (from imageio==2.25.1) (10.3.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: pysrt==1.1.2 in c:\python312\lib\site-packages (1.1.2)
# Requirement already satisfied: chardet in c:\python312\lib\site-packages (from pysrt==1.1.2) (5.2.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting google-colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      ---------------------------------------- 0.0/72.9 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/72.9 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/72.9 kB ? eta -:--:--
#      ---------------- --------------------- 30.7/72.9 kB 217.9 kB/s eta 0:00:01
#      ---------------- --------------------- 30.7/72.9 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------  71.7/72.9 kB 280.5 kB/s eta 0:00:01
#      -------------------------------------- 72.9/72.9 kB 286.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting google-auth~=1.4.0 (from google-colab)
#   Obtaining dependency information for google-auth~=1.4.0 from https://files.pythonhosted.org/packages/56/80/369a47c28ce7d9be6a6973338133d073864d8efbb62747e414c34a3a5f4f/google_auth-1.4.2-py2.py3-none-any.whl.metadata
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting ipykernel~=4.6.0 (from google-colab)
#   Obtaining dependency information for ipykernel~=4.6.0 from https://files.pythonhosted.org/packages/18/c3/76775a650cae2e3d9c033b26153583e61282692d9a3af12a3022d8f0cefa/ipykernel-4.6.1-py3-none-any.whl.metadata
#   Downloading ipykernel-4.6.1-py3-none-any.whl.metadata (981 bytes)
# Collecting ipython~=5.5.0 (from google-colab)
#   Obtaining dependency information for ipython~=5.5.0 from https://files.pythonhosted.org/packages/07/63/c987612bcf82c56eaacaf6bf01e31e53a244a0a3a0fb036ec5adc377e0fe/ipython-5.5.0-py3-none-any.whl.metadata
#   Downloading ipython-5.5.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting notebook~=5.2.0 (from google-colab)
#   Obtaining dependency information for notebook~=5.2.0 from https://files.pythonhosted.org/packages/96/a2/d951ebb7855743f989287486ded73cd3f66915c3ecd9c5c5a0c7ca12377a/notebook-5.2.2-py2.py3-none-any.whl.metadata
#   Downloading notebook-5.2.2-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting six~=1.12.0 (from google-colab)
#   Obtaining dependency information for six~=1.12.0 from https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl.metadata
#   Downloading six-1.12.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pandas~=0.24.0 (from google-colab)
#   Downloading pandas-0.24.2.tar.gz (11.8 MB)
#      ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/11
8 MB 1.9 MB/s eta 0:00:04
#      ------------------- -------------------- 5.8/11.8 MB 2.0 MB/s eta 0:00:04
#      ------------------- -------------------- 5.9/11.8 MB 2.0 MB/s eta 0:00:04
#      -------------------- ------------------- 6.1/11.8 MB 2.0 MB/s eta 0:00:03
#      --------------------- ------------------ 6.2/11.8 MB 2.0 MB/s eta 0:00:03
#      --------------------- ------------------ 6.4/11.8 MB 2.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 6.6/11.8 MB 2.1 MB/s eta 0:00:03
#      ----------------------- ---------------- 6.8/11.8 MB 2.1 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.0/11.8 MB 2.2 MB/s eta 0:00:03
#      ------------------------ --------------- 7.2/11.8 MB 2.2 MB/s eta 0:00:03
#      ------------------------- -------------- 7.4/11.8 MB 2.2 MB/s eta 0:00:02
#      ------------------------- -------------- 7.6/11.8 MB 2.3 MB/s eta 0:00:02
#      -------------------------- ------------- 7.9/11.8 MB 2.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.1/11.8 MB 2.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.3/11.8 MB 2.4 MB/s eta 0:00:02
#      ---------------------------- ----------- 8.5/11.8 MB 2.4 MB/s eta 0:00:02
#      ----------------------------- ---------- 8.7/11.8 MB 2.4 MB/s eta 0:00:02
#      ------------------------------ --------- 9.0/11.8 MB 2.5 MB/s eta 0:00:02
#      ------------------------------- -------- 9.2/11.8 MB 2.5 MB/s eta 0:00:02
#      -------------------------------- ------- 9.5/11.8 MB 2.5 MB/s eta 0:00:01
#      -------------------------------- ------- 9.8/11.8 MB 2.6 MB/s eta 0:00:01
#      --------------------------------- ------ 10.0/11.8 MB 2.6 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.3/11.8 MB 2.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 10.5/11.8 MB 2.8 MB/s eta 0:00:01
#      ------------------------------------ --- 10.8/11.8 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------- -- 11.1/11.8 MB 3.3 MB/s eta 0:00:01
#      -------------------------------------- - 11.3/11.8 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------  11.6/11.8 MB 3.5 MB/s eta 0:00:01
#      ---------------------------------------  11.8/11.8 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------- 11.8/11.8 MB 3.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [30 lines of output]
#       <string>:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#       Traceback (most recent call last):
#         File "C:\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-build-env-85lscqjk\overlay\Lib\site-packages\setuptools\build_meta.py", line 325, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel'])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-build-env-85lscqjk\overlay\Lib\site-packages\setuptools\build_meta.py", line 295, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-build-env-85lscqjk\overlay\Lib\site-packages\setuptools\build_meta.py", line 487, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-build-env-85lscqjk\overlay\Lib\site-packages\setuptools\build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 732, in <module>
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-install-c7apm5tq\pandas_bd39c6e6827048a1b5ca518d2b3aed85\versioneer.py", line 1409, in get_version
#           return get_versions()["version"]
#                  ^^^^^^^^^^^^^^
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-install-c7apm5tq\pandas_bd39c6e6827048a1b5ca518d2b3aed85\versioneer.py", line 1343, in get_versions
#           cfg = get_config_from_root(root)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\Abdurahmon\AppData\Local\Temp\pip-install-c7apm5tq\pandas_bd39c6e6827048a1b5ca518d2b3aed85\versioneer.py", line 399, in get_config_from_root
#           parser = configparser.SafeConfigParser()
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'configparser' has no attribute 'SafeConfigParser'. Did you mean: 'RawConfigParser'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 8
#       5 get_ipython().system('pip install pysrt==1.1.2')
#       6 get_ipython().system('pip install google-colab')
# ----> 8 from google.colab import drive
#       9 drive.mount('/content/gdrive/', force_remount=True)
#
# ModuleNotFoundError: No module named 'google'

# %%
import sys
import pysrt
from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip

def time_to_seconds(time_obj):
    return time_obj.hours * 3600 + time_obj.minutes * 60 + time_obj.seconds + time_obj.milliseconds / 1000

def create_subtitle_clips(subtitles, videosize,fontsize=24, font='Arial', color='yellow', debug = False):
    subtitle_clips = []

    for subtitle in subtitles:
        start_time = time_to_seconds(subtitle.start)
        end_time = time_to_seconds(subtitle.end)
        duration = end_time - start_time

        video_width, video_height = videosize
        
        text_clip = TextClip(subtitle.text, fontsize=fontsize, font=font, color=color, bg_color='black', size=(video_width*3/4, None), method='caption').set_start(start_time).set_duration(duration)
        subtitle_x_position = 'center'
        subtitle_y_position = video_height * 4 / 5 

        text_position = (subtitle_x_position, subtitle_y_position)                    
        subtitle_clips.append(text_clip.set_position(text_position))

    return subtitle_clips

# %%
# Load video and SRT file
srtfilename = "./main.srt"
mp4filename = "./Приветствие.mp4"
video = VideoFileClip(mp4filename)
subtitles = pysrt.open(srtfilename)

begin,end= mp4filename.split(".mp4")
output_video_file = begin+'_subtitled'+".mp4"

print ("Output file name: ",output_video_file)

# Create subtitle clips
subtitle_clips = create_subtitle_clips(subtitles, video.size)

# Add subtitles to the video
final_video = CompositeVideoClip([video] + subtitle_clips)

# Write output video file
final_video.write_videofile(output_video_file)

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open(output_video_file, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
""" % data_url)

# %%
import sys
import pysrt
from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip

def time_to_seconds(time_obj):
    return time_obj.hours * 3600 + time_obj.minutes * 60 + time_obj.seconds + time_obj.milliseconds / 1000

def create_subtitle_clips(subtitles, videosize, fontsize=24, font='Arial', color='yellow', debug=False):
    subtitle_clips = []

    for subtitle in subtitles:
        start_time = time_to_seconds(subtitle.start)
        end_time = time_to_seconds(subtitle.end)
        duration = end_time - start_time

        video_width, video_height = videosize

        text_clip = TextClip(subtitle.text, fontsize=fontsize, font=font, color=color, bg_color='black', size=(video_width*3/4, None), method='caption').set_start(start_time).set_duration(duration)
        subtitle_x_position = 'center'
        subtitle_y_position = video_height * 4 / 5

        text_position = (subtitle_x_position, subtitle_y_position)
        subtitle_clips.append(text_clip.set_position(text_position))

    return subtitle_clips


# Load video and SRT file
srtfilename = "/main.srt"
mp4filename = "/Приветствие.mp4"

video = VideoFileClip(mp4filename)
subtitles = pysrt.open(srtfilename)

begin, end = mp4filename.split(".mp4")
output_video_file = begin+'_subtitled'+".mp4"

print("Output file name: ", output_video_file)

# Create subtitle clips
subtitle_clips = create_subtitle_clips(subtitles, video.size)

# Add subtitles to the video
final_video = CompositeVideoClip([video] + subtitle_clips)

# Write output video file
final_video.write_videofile(output_video_file)

# Show the video
final_video.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[38], line 32
#      29 srtfilename = "/main.srt"
#      30 mp4filename = "/Приветствие.mp4"
# ---> 32 video = VideoFileClip(mp4filename)
#      33 subtitles = pysrt.open(srtfilename)
#      35 begin, end = mp4filename.split(".mp4")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\decorator.py:232, in fun(*args, **kw)
#
# File c:\Python312\Lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      84 new_a = [
#      85     fun(arg) if (name in varnames) and (arg is not None) else arg
#      86     for (arg, name) in zip(a, names)
#      87 ]
#      88 new_kw = {k: fun(v) if k in varnames else v for (k, v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File c:\Python312\Lib\site-packages\moviepy\video\io\VideoFileClip.py:103, in VideoFileClip.__init__(self, filename, decode_file, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, fps_source, pix_fmt)
#     101 if not pix_fmt:
#     102     pix_fmt = "rgba" if has_mask else "rgb24"
# --> 103 self.reader = FFMPEG_VideoReader(
#     104     filename,
#     105     decode_file=decode_file,
#     106     pix_fmt=pix_fmt,
#     107     target_resolution=target_resolution,
#     108     resize_algo=resize_algorithm,
#     109     fps_source=fps_source,
#     110 )
#     112 # Make some of the reader's attributes accessible from the clip
#     113 self.duration = self.reader.duration
#
# File c:\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:35, in FFMPEG_VideoReader.__init__(self, filename, decode_file, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
#      33 self.filename = filename
#      34 self.proc = None
# ---> 35 infos = ffmpeg_parse_infos(
#      36     filename, decode_file, print_infos, check_duration, fps_source
#      37 )
#      38 self.fps = infos["video_fps"]
#      39 self.size = infos["video_size"]
#
# File c:\Python312\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:321, in ffmpeg_parse_infos(filename, decode_file, print_infos, check_duration, fps_source)
#     319 lines = infos.splitlines()
#     320 if "No such file or directory" in lines[-1]:
# --> 321     raise IOError(
#     322         (
#     323             "MoviePy error: the file %s could not be found!\n"
#     324             "Please check that you entered the correct "
#     325             "path."
#     326         )
#     327         % filename
#     328     )
#     330 result = dict()
#     332 # get duration (in seconds)
#
# OSError: MoviePy error: the file /Приветствие.mp4 could not be found!
# Please check that you entered the correct path.
